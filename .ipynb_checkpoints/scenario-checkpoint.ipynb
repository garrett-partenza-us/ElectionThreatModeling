# %%
import pandas as pd

# %%
tree = pd.read_csv('tree.csv', header=None)
tree.columns = ['Type', 'Code', 'Unknown1', 'Description', 'Prob', 'Unknown2']
tree.head()
# Out:
#   Type    Code Unknown1                Description      Prob  Unknown2
# 0    O       0      NaN                       root       NaN       NaN
# 1    A       1      NaN   attack voting equipment        NaN       NaN
# 2    O     1.1      NaN           gather knowledge       NaN       NaN
# 3    T   1.1.1       X1               from insider  0.068889       2.0
# 4    A   1.1.2      NaN            from components       NaN       NaN

# %%
import networkx as nx

G = nx.DiGraph()

for index, row in tree.iterrows():
    
    node = row['Code'].strip()
    
    G.add_node(node, node_type=row['Type'], prob=row['Prob'])
    
    if node == '0':
        continue
        
    u = '.'.join(node.split('.')[:-1])
    v = '.'.join(node.split('.'))
    
    if not u:
        G.add_edge('0',v)
    else:
        G.add_edge(u,v)

# %%
nx.draw(G)

# %%
bfs = list(nx.bfs_edges(G, source='0'))
bfs.reverse()

# %%
bfs = list(n[1] for n in bfs)

# %%
import numpy as np

for node in bfs:
    if G.nodes[node]['node_type'] in ['A', 'O']:
        
        n_probs = []
        
        for n in G.neighbors(node):
            n_probs.append(G.nodes[n]['prob'])
                    
        if G.nodes[node]['node_type'] == 'A':
            G.nodes[node]['prob'] = np.prod(n_probs)
            
        if G.nodes[node]['node_type'] == 'O':
            #https://stackoverflow.com/questions/56266279/compute-probability-of-union-of-n-events-from-array
            diffs = list(1-n for n in n_probs)
            G.nodes[node]['prob'] = np.prod(diffs)

#finish with root node
n_probs = []
for n in G.neighbors('0'):
    n_probs.append(G.nodes[n]['prob'])
G.nodes['0']['prob'] = np.sum(n_probs)

# %%
data = []
for node in G.nodes():
    prob = G.nodes[node]['prob']
    kind = G.nodes[node]['node_type']
    inputs = list(zip(list(G.neighbors(node)), list(G.nodes[n]['prob'] for n in G.neighbors(node))))
    data.append((node,prob,kind, inputs))
    
results = pd.DataFrame(data, columns=['Code','Probability','Type','Inputs'])
results.to_csv('results.csv')

# %%
import copy
import time

def get_scenarios(node):
    paths = [[node]]
    bfs = [node] + list(n[1] for n in list(nx.bfs_edges(G, source=node)))
    for node in bfs:
        paths = traverse(node, paths)
    probs = []
    for path in paths:
        temp = []
        for node in path:
            if G.nodes[node]['node_type']=='T':
                temp.append(G.nodes[node]['prob'])
        probs.append(np.prod(temp))
    return list(zip(paths,probs))
        
def traverse(node, paths):
#     time.sleep(1)
    if G.nodes[node]['node_type'] == 'O':
        new_paths = []
        to_remove = []
        for i in range(len(paths)):
            path = paths[i]
            #G.pred[1.3.2.4]
            if node in path[-len(list(G.neighbors(list(G.pred[node])[0]))):]:
                to_remove.append(i)
                for n in G.neighbors(node):
                    new_paths.append(path+[n])
        for d in sorted(to_remove, reverse=True):
            paths.pop(d)
        paths = paths+new_paths
            
    if G.nodes[node]['node_type'] == 'A':
        for path in paths:
            if node in path:
                for n in G.neighbors(node):
                    path.append(n)
    return paths

# %%
import numpy as np 

data = []
for i, node in enumerate(G.nodes()):
    print(i)
    prob = G.nodes[node]['prob']
    kind = G.nodes[node]['node_type']
    inputs = list(zip(list(G.neighbors(node)), list(G.nodes[n]['prob'] for n in G.neighbors(node))))
    if node in ['0','1','2','3','4','5','6','7']:
        scenarios = 'N/A'
        scenario_count = 'N/A'
        total_of_scenario_prob = 'N/A'
    else:
        scenarios = get_scenarios(node)
        scenario_count = len(scenarios)
        total_of_scenario_prob = np.prod(list(1-n[1] for n in scenarios))
    data.append((node,prob,kind, inputs, scenario_count, total_of_scenario_prob, scenarios))
    
results = pd.DataFrame(data, columns=['Code','Probability','Type','Inputs','Scenario_Count','Sum of Scenario Probabilities', 'Scenarios'])
results.to_csv('results.csv')

# %%
import numpy as np 
tree['Code']=tree['Code'].str.strip()
tree['Unknown1']=tree['Unknown1'].str.strip()

node_dict = dict(zip(tree.Code, tree.Unknown1))
phase_dict = dict(zip(tree.Unknown1, tree.Unknown2))


data = []
for i, node in enumerate(node for node in G.nodes() if G.nodes[node]['node_type']!='T'):
    scenario_num = "S"+str(i)
    logic_gate = str(node)
    description = tree[tree['Code']==node.strip()]['Description'].tolist()[0].strip()
    if node in ['0','1','2','3','4','5','6','7']:
        terminal_nodes = 'N/A'
        terminal_nodes_Xs = 'N/A'
        occurrence_probability = 'N/A'
        phases = 'N/A'
        data.append((scenario_num, 
                        logic_gate, 
                        description, 
                        terminal_nodes, 
                        terminal_nodes_Xs, 
                        occurrence_probability, 
                        phases))
    else:
        for scenario in get_scenarios(node):
            terminal_nodes = list(n for n in scenario[0] if G.nodes[n]['node_type']=='T')
            terminal_nodes_Xs = list(node_dict[n] for n in terminal_nodes)
            occurrence_probability = scenario[1]
            phases = list(phase_dict[n] for n in terminal_nodes_Xs)
            terminal_nodes = ', '.join(terminal_nodes)
            terminal_nodes_Xs = ', '.join(list(map(str, terminal_nodes_Xs)))
            phases = ', '.join(list(map(str, phases)))
            data.append((scenario_num, 
                        logic_gate, 
                        description, 
                        terminal_nodes, 
                        terminal_nodes_Xs, 
                        occurrence_probability, 
                        phases))

# %%
results = pd.DataFrame(data, columns=['Scenario #', 'Logic Gate #', 'Logic Gate Description', ' Terminal Nodes', 'Terminal Nodes (X#s)', 'Occurrence Probability', 'Phases'])
results.to_csv('results.csv')
